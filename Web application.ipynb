# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('Times_Square_Hotels.csv')
df.head()
# Out:
#                    Company Name        Address           Phone  \
# 0               Paramount Hotel  235 W 46th St  (212) 764-5500
# 1                  Carter Hotel  250 W 43rd St  (212) 944-6000
# 2              Millennium Hotel  145 W 44th St  (212) 768-4400
# 3  Best Western President Hotel  234 W 48th St  (212) 246-8800
# 4                       Novotel  226 W 52nd St  (212) 315-0100
#
#                               Website               Location 1  Borough  \
# 0         http://www.nycparamount.com  (40.759132, -73.986348)        1
# 1                                 NaN  (40.757309, -73.987901)        1
# 2  http://www.millenniumhotelnyc.com/  (40.756667, -73.984396)        1
# 3          http://www.bestwestern.com  (40.760454, -73.985655)        1
# 4                     www.novotel.com  (40.762897, -73.983683)        1
#
#    Postcode   Latitude  Longitude  Community Board  Community Council   \
# 0     10036  40.759132 -73.986348                5                   3
# ...

# %%
conn = sqlite3.connect("hotels.db")

# %%
df.shape
# Out:
# (41, 15)

# %%
df[df.BBL == 1009990017]
# Out:
#            Company Name        Address           Phone             Website  \
# 23  Comfort Inn Midtown  129 W 46th St  (212) 221-2600  www.comfortinn.com
# 34   Remington Hotel Co  129 W 46th St  (212) 221-2600                 NaN
#
#                 Location 1  Borough  Postcode   Latitude  Longitude  \
# 23  (40.757811, -73.98323)        1     10036  40.757811  -73.98323
# 34  (40.757811, -73.98323)        1     10036  40.757811  -73.98323
#
#     Community Board  Community Council   Census Tract      BIN         BBL  \
# 23                5                   4           125  1022666  1009990017
# 34                5                   4           125  1022666  1009990017
#
#                                                   NTA
# 23  Midtown-Midtown South                         ...
# 34  Midtown-Midtown South                         ...

# %%
df.drop(df.index[34], inplace=True)

# %%
df.BBL.value_counts()
# Out:
# 1009970047    1
# 1010167501    1
# 1009970010    1
# 1010180018    1
# 1010140055    1
# 1010230029    1
# 1010197501    1
# 1010370036    1
# 1010427501    1
# 1010050001    1
# 1009980047    1
# 1010207501    1
# 1009990061    1
# 1009960009    1
# 1010000007    1
# 1010340037    1
# 1010210052    1
# 1010240131    1
# 1010230018    1
# 1010130012    1
# 1010057501    1
# 1009990048    1
# 1010200046    1
# 1010140058    1
# 1009980026    1
# 1010200057    1
# 1009980023    1
# 1010360052    1
# 1010200051    1
# 1009980018    1
# 1010187501    1
# 1010037501    1
# 1009990017    1
# 1009960043    1
# 1010170029    1
# 1010190055    1
# 1010180006    1
# 1010120037    1
# 1009970019    1
# 1010370035    1
# Name: BBL, dtype: int64

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df
# Out:
#                             Company_Name          Address  \
# 0                        Paramount Hotel    235 W 46th St
# 1                           Carter Hotel    250 W 43rd St
# 2                       Millennium Hotel    145 W 44th St
# 3           Best Western President Hotel    234 W 48th St
# 4                                Novotel    226 W 52nd St
# 5                            Dream Hotel    1674 Broadway
# 6                                W Hotel    1567 Broadway
# 7                Doubletree Guest Suites    1568 Broadway
# 8                             Stay Hotel    157 W 47th St
# 9               Hotel 41 At Times Square    206 W 41st St
# 10                       Time Hotel, The    224 W 49th St
# 11                   Hilton Times Square    234 W 42nd St
# 12   The Westin New York at Times Square    270 W 43rd St
# 13             Crowne Plaza Times Square    1605 Broadway
# 14              Renaissance Times Square  714 Seventh Ave
# ...

# %%
df.to_sql('hotelsts', conn)
